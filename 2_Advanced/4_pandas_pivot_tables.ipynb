# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.pivot_table(values = "salary_year_avg",index="job_country",columns = "job_title_short", aggfunc = "median")
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Albania                       NaN             NaN      49950.00
# Algeria                       NaN             NaN      44100.00
# Argentina                 71100.0        197500.0      92771.75
# Armenia                       NaN             NaN     100500.00
# Australia                 70000.0        110000.0     109500.00
# ...                           ...             ...           ...
# Uruguay                       NaN             NaN     100500.00
# Uzbekistan                    NaN             NaN           NaN
# Vietnam                   79200.0             NaN      75550.00
# Zambia                        NaN             NaN           NaN
# Zimbabwe                      NaN             NaN      63000.00
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Albania                    NaN        69981.25                        NaN
# ...

# %%
top_countries = df['job_country'].value_counts().head(6).index
df_country_salary = df.pivot_table(values = "salary_year_avg",index="job_country",columns = "job_title_short", aggfunc = "median")
df_country_salary = df_country_salary.loc[top_countries]
job_titles = ['Data Scientist', 'Data Engineer', 'Data Analyst']

df_country_salary = df_country_salary[job_titles]
df_country_salary.plot(kind='bar')
plt.title('Average Salary by Job Title and Country')
plt.ylabel('Average Salary (Yearly)')
plt.xlabel('Country')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'United States'),
#   Text(1, 0, 'India'),
#   Text(2, 0, 'United Kingdom'),
#   Text(3, 0, 'France'),
#   Text(4, 0, 'Germany'),
#   Text(5, 0, 'Spain')])
